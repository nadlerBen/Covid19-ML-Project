# %%
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import convert_data_to_lstm as cdtl
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
import matplotlib.pyplot as plt

torch.manual_seed(1)

# %%
def argmax(vector):
    # return argmax of the vector
    _, idx = torch.max(vector, 1)
    return idx

# %%
class biLSTM(nn.Module):
    def __init__(self, class_to_ix, features_dim, hidden_dim):
        super(biLSTM, self).__init__()
        self.features_dim = features_dim
        self.hidden_dim = hidden_dim
        self.class_to_ix = class_to_ix
        self.target_size = len(class_to_ix)
        # biLSTM init
        self.lstm = nn.LSTM(features_dim, hidden_dim // 2,
                            num_layers=1, bidirectional=True)
        # maps the output of the lstm into the classes space
        self.hidden_to_class = nn.Linear(hidden_dim, self.target_size)

    def init_hidden(self):
        return (torch.randn(2, 1, self.hidden_dim // 2),
                torch.randn(2, 1, self.hidden_dim // 2))

    def forward(self, sequence):
        self.hidden = self.init_hidden()
        sequence = sequence.view(len(sequence), 1, -1)
        lstm_out, self.hidden = self.lstm(sequence, self.hidden)
        lstm_out = lstm_out.view(len(sequence), self.hidden_dim)
        lstm_features = self.hidden_to_class(lstm_out)
        lstm_features = F.log_softmax(lstm_features, dim=1)
        return lstm_features

# %%
def calc_accuracy(gold, predictions):
    count = 0
    for idx in range(len(gold)):
        if gold[idx] == predictions[idx]:
            count += 1
    return count

# %%
def predict_sequences(training_data, test_data, model):
    y_pred = []
    y_true = []
    with torch.no_grad():
        prechecks = [data[0] for data in training_data]
        labels = [data[1] for data in training_data]
        prechecks = torch.tensor(prechecks, dtype=torch.float)
        total_correct = 0
        total_predictions = len(prechecks)
        for idx, precheck in enumerate(prechecks):
            labels[idx] = [int(num) for num in labels[idx]]
            outputs = argmax(model(precheck))
            for output in outputs:
                y_pred.append(output)
            for label in labels[idx]:
                y_true.append(label)
            total_correct += calc_accuracy(labels[idx], outputs)
        #train_acc = total_correct/(total_predictions * 7)
        train_acc = accuracy_score(y_true, y_pred)
        f1score_train = f1_score(y_true, y_pred, average='weighted')
        precision_train = precision_score(y_true, y_pred, average='weighted')
        recall_train = recall_score(y_true, y_pred, average='weighted')
        print(
            f'model accuracy after training: {train_acc}')
        print(f'model f1 score for training: {f1score_train}')
        print(f'model precision score for training: {precision_train}')
        print(f'model recall score for training: {recall_train}')
    y_pred = []
    y_true = []
    with torch.no_grad():
        prechecks = [data[0] for data in test_data]
        labels = [data[1] for data in test_data]
        total_correct = 0
        total_predictions = len(prechecks)
        prechecks = torch.tensor(prechecks, dtype=torch.float)
        for idx, precheck in enumerate(prechecks):
            labels[idx] = [int(num) for num in labels[idx]]
            outputs = argmax(model(precheck))
            for output in outputs:
                y_pred.append(output)
            for label in labels[idx]:
                y_true.append(label)
            total_correct += calc_accuracy(labels[idx], outputs)
        #test_acc = total_correct/(total_predictions * 7)
        test_acc = accuracy_score(y_true, y_pred)
        f1score_test = f1_score(y_true, y_pred, average='weighted')
        precision_test = precision_score(y_true, y_pred, average='weighted')
        recall_test = recall_score(y_true, y_pred, average='weighted')
        print(
            f'model accuracy after test: {test_acc}')
        print(f'model f1 score for training: {f1score_test}')
        print(f'model precision score for test: {precision_test}')
        print(f'model recall score for test: {recall_test}')
    return train_acc, test_acc, f1score_train, f1score_test, precision_train, precision_test, recall_train, recall_test

# %%
def main():
    #####################################################################
    # data loader and manipulation:
    #####################################################################
    covid = cdtl.load_data()
    HIDDEN_DIM = 16
    FEATURES_DIM = len(covid.drop(
        [' Country', 'Date', 'target'], axis=1).columns)
    countries = cdtl.get_country_names(covid)
    training_data = cdtl.data_to_lstm_input(
        covid, countries, '2020-03-05', '2020-07-16')
    test_data = cdtl.data_to_lstm_input(
        covid, countries, '2020-07-16', '2020-08-11')
    classes_to_ix = {0: 0, 1: 1, 2: 2, 3: 3, 4: 4}
    num_tags = 5 #change back to 4 after tests
    #####################################################################
    # initialize model and optimizer:
    #####################################################################
    model = biLSTM(classes_to_ix, FEATURES_DIM, HIDDEN_DIM)
    criterion = nn.NLLLoss()
    #optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4, betas=(0.9, 0.99))
    optimizer = optim.SGD(model.parameters(), lr=0.01)
    accumulated_grad_steps = 1
    #####################################################################
    # training:
    #####################################################################
    model.train()
    total_train_acc_values = []
    total_test_acc_values = []
    total_f1_train_values = []
    total_f1_test_values = []
    total_precision_train_values = []
    total_precision_test_values = []
    total_recall_train_values = []
    total_recall_test_values = []
    epoch_loss = []
    best_test_acc = 0.60
    for epoch in range(
            100):
        count = 0
        total_epoch_loss = 0
        i = 0
        loss_values = []
        train_acc_values = []
        test_acc_values = []
        f1_train_values = []
        f1_test_values = []
        precision_train_values = []
        precision_test_values = []
        recall_train_values = []
        recall_test_values = []
        print('Number of epoch: {}'.format(epoch))
        for country in countries:
            print(f'Training on {country}')
            for sequence, classes in training_data[country]:
                i += 1
                sequence = torch.tensor(sequence, dtype=torch.float)
                classes = torch.tensor(classes, dtype=torch.long)
                lstm_features = model(sequence)
                loss = criterion(lstm_features, classes)
                loss = loss / accumulated_grad_steps
                loss.backward()

                if i % accumulated_grad_steps == 0:
                    optimizer.step()
                    model.zero_grad()

                total_epoch_loss += loss.item()
                count += 1
            print(f'Average loss for epoch {epoch}: {total_epoch_loss/count}')
            loss_values.append(total_epoch_loss/count)

            train_acc, test_acc, f1_train, f1_test, precision_train, precision_test, recall_train, recall_test = predict_sequences(training_data[country], test_data[country], model)
            train_acc_values.append(train_acc)
            test_acc_values.append(test_acc) 
            f1_train_values.append(f1_train)
            f1_test_values.append(f1_test)
            precision_train_values.append(precision_train)
            precision_test_values.append(precision_test)
            recall_train_values.append(recall_train)
            recall_test_values.append(recall_test)
        total_loss = sum(loss_values) / len(countries)
        total_train_acc = sum(train_acc_values) / len(countries)
        total_test_acc = sum(test_acc_values) / len(countries)
        total_f1_train = sum(f1_train_values) / len(countries)
        total_f1_test = sum(f1_test_values) / len(countries)
        total_precision_train = sum(precision_train_values) / len(countries)
        total_precision_test = sum(precision_test_values) / len(countries)
        total_recall_train = sum(recall_train_values) / len(countries)
        total_recall_test = sum(recall_test_values) / len(countries)
        print(f'total train acc for epoch {epoch}: {total_train_acc}, total test acc for epoch {epoch}: {total_test_acc}')
        print(f'total train f1 score for epoch {epoch}: {total_f1_train}, total test f1 score for epoch {epoch}: {total_f1_test} ')
        print(f'total train precision score for epoch {epoch}: {total_precision_train}, total test precision score for epoch {epoch}: {total_precision_test} ')
        print(f'total train recall score for epoch {epoch}: {total_recall_train}, total test recall score for epoch {epoch}: {total_recall_test} ')
        epoch_loss.append(total_loss)
        total_train_acc_values.append(total_train_acc)
        total_test_acc_values.append(total_test_acc)
        total_f1_train_values.append(total_f1_train)
        total_f1_test_values.append(total_f1_test)
        total_precision_train_values.append(total_precision_train)
        total_precision_test_values.append(total_precision_test)
        total_recall_train_values.append(total_recall_train)
        total_recall_test_values.append(total_recall_test)
        if total_test_acc > best_test_acc and total_train_acc > total_test_acc:
            best_test_acc = total_test_acc
            torch.save(model.state_dict(), f'final_lstm_no_crf_pickle_one_month_world_model_{total_train_acc}_train_acc_{best_test_acc}_test_acc_{epoch}_epoch_allfeatures.pkl')
            torch.save(model.state_dict(), f'final_lstm_no_crf_one_month_world_model_{total_train_acc}_train_acc_{best_test_acc}_test_acc_{epoch}_epoch_allfeatures.pth')
            torch.save(model, f'final_lstm_no_crf_entire_model_one_month_world_{total_train_acc}_train_acc_{best_test_acc}_test_acc_{epoch}_epoch_allfeatures.pth')
    plt.plot(total_train_acc_values)
    plt.plot(total_test_acc_values)
    plt.show()
    plt.plot(epoch_loss)
    plt.show()
    plt.plot(total_f1_train_values)
    plt.plot(total_f1_test_values)
    plt.show()
    plt.plot(total_precision_train_values)
    plt.plot(total_precision_test_values)
    plt.show()
    plt.plot(total_recall_train_values)
    plt.plot(total_recall_test_values)
    plt.show()

# %%
if __name__ == "__main__":
    main()
# Out:
# Working on Brazil
# Working on Germany
# Working on Italy
# Working on United States of America
# Working on United Arab Emirates
# Working on Israel
# Working on Republic of Korea
# Working on India
# Working on Saudi Arabia
# Working on Mexico
# Working on Japan
# Working on Brazil
# Working on Germany
# Working on Italy
# Working on United States of America
# Working on United Arab Emirates
# Working on Israel
# Working on Republic of Korea
# Working on India
# Working on Saudi Arabia
# Working on Mexico
# Working on Japan
# Number of epoch: 0
# Training on Brazil
# <ipython-input-49-668f676c1d73>:58: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   classes = torch.tensor(classes, dtype=torch.long)
# Average loss for epoch 0: 1.5274169212207198
# model accuracy after training: 0.3470982142857143
# model f1 score for training: 0.24022525608034803
# model precision score for training: 0.21832515086710794
# model recall score for training: 0.3470982142857143
# model accuracy after test: 0.24489795918367346
# model f1 score for training: 0.29673562788959984
# model precision score for test: 0.8166266506602641
# model recall score for test: 0.24489795918367346
# Training on Germany
# /usr/local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average loss for epoch 0: 1.4257855664473027
# model accuracy after training: 0.6629464285714286
# model f1 score for training: 0.5323781124676542
# model precision score for training: 0.5242407711402947
# model recall score for training: 0.6629464285714286
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Italy
# Average loss for epoch 0: 1.323637072307368
# model accuracy after training: 0.4799107142857143
# model f1 score for training: 0.31125430941607407
# model precision score for training: 0.2303142936862245
# model recall score for training: 0.4799107142857143
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on United States of America
# Average loss for epoch 0: 1.3144877080339938
# model accuracy after training: 0.6875
# model f1 score for training: 0.5601851851851852
# model precision score for training: 0.47265625
# model recall score for training: 0.6875
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on United Arab Emirates
# /usr/local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average loss for epoch 0: 1.2991157207638024
# model accuracy after training: 0.5859375
# model f1 score for training: 0.4329587438423645
# model precision score for training: 0.34332275390625
# model recall score for training: 0.5859375
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Israel
# Average loss for epoch 0: 1.2904884116724133
# model accuracy after training: 0.5
# model f1 score for training: 0.3333333333333333
# model precision score for training: 0.25
# model recall score for training: 0.5
# model accuracy after test: 0.11564625850340136
# model f1 score for training: 0.023975443836071017
# model precision score for test: 0.013374057105835531
# model recall score for test: 0.11564625850340136
# Training on Republic of Korea
# Average loss for epoch 0: 1.3253273194921869
# model accuracy after training: 0.6216517857142857
# model f1 score for training: 0.5454100647444654
# model precision score for training: 0.556519261155955
# model recall score for training: 0.6216517857142857
# model accuracy after test: 0.7346938775510204
# model f1 score for training: 0.6855726958174312
# model precision score for test: 0.7308893927941548
# model recall score for test: 0.7346938775510204
# Training on India
# Average loss for epoch 0: 1.3035073359496891
# model accuracy after training: 0.5691964285714286
# model f1 score for training: 0.4157277939809089
# model precision score for training: 0.43965507185516983
# model recall score for training: 0.5691964285714286
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on Saudi Arabia
# Average loss for epoch 0: 1.3218857528020937
# model accuracy after training: 0.48660714285714285
# model f1 score for training: 0.35073817963162224
# model precision score for training: 0.31082589285714285
# model recall score for training: 0.48660714285714285
# model accuracy after test: 0.8979591836734694
# model f1 score for training: 0.9462365591397849
# model precision score for test: 1.0
# model recall score for test: 0.8979591836734694
# Training on Mexico
# Average loss for epoch 0: 1.3031824280507862
# model accuracy after training: 0.4921875
# model f1 score for training: 0.3246891361256545
# model precision score for training: 0.24224853515625
# model recall score for training: 0.4921875
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Japan
# Average loss for epoch 0: 1.3009793751619079
# model accuracy after training: 0.5792410714285714
# model f1 score for training: 0.5272364187369052
# model precision score for training: 0.5387546079088471
# model recall score for training: 0.5792410714285714
# model accuracy after test: 0.14965986394557823
# model f1 score for training: 0.25867136978248095
# model precision score for test: 0.9523809523809523
# model recall score for test: 0.14965986394557823
# total train acc for epoch 0: 0.5465706168831169, total test acc for epoch 0: 0.5584415584415585
# total train f1 score for epoch 0: 0.4158305939585923, total test f1 score for epoch 0: 0.5646537905877607
# total train precision score for epoch 0: 0.3751693262302947, total test precision score for epoch 0: 0.6830246411764733
# total train recall score for epoch 0: 0.5465706168831169, total test recall score for epoch 0: 0.5584415584415585
# Number of epoch: 1
# Training on Brazil
# Average loss for epoch 1: 1.5845316271297634
# model accuracy after training: 0.3325892857142857
# model f1 score for training: 0.2257697002839496
# model precision score for training: 0.2282281490366947
# model recall score for training: 0.3325892857142857
# model accuracy after test: 0.061224489795918366
# model f1 score for training: 0.013824884792626727
# model precision score for test: 0.007792207792207792
# model recall score for test: 0.061224489795918366
# Training on Germany
# Average loss for epoch 1: 1.310459922067821
# model accuracy after training: 0.6651785714285714
# model f1 score for training: 0.531429528916124
# model precision score for training: 0.4424625318877551
# model recall score for training: 0.6651785714285714
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Italy
# Average loss for epoch 1: 1.2057461263611913
# model accuracy after training: 0.4799107142857143
# model f1 score for training: 0.31125430941607407
# model precision score for training: 0.2303142936862245
# model recall score for training: 0.4799107142857143
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on United States of America
# Average loss for epoch 1: 1.2311511575244367
# model accuracy after training: 0.6875
# model f1 score for training: 0.5601851851851852
# model precision score for training: 0.47265625
# model recall score for training: 0.6875
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on United Arab Emirates
# Average loss for epoch 1: 1.2200206604786217
# model accuracy after training: 0.5859375
# model f1 score for training: 0.4329587438423645
# model precision score for training: 0.34332275390625
# model recall score for training: 0.5859375
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Israel
# Average loss for epoch 1: 1.2180835890661303
# model accuracy after training: 0.5
# model f1 score for training: 0.3333333333333333
# model precision score for training: 0.25
# model recall score for training: 0.5
# model accuracy after test: 0.11564625850340136
# model f1 score for training: 0.023975443836071017
# model precision score for test: 0.013374057105835531
# model recall score for test: 0.11564625850340136
# Training on Republic of Korea
# Average loss for epoch 1: 1.2451873837105398
# model accuracy after training: 0.6707589285714286
# model f1 score for training: 0.5518596913563216
# model precision score for training: 0.5272595062429057
# model recall score for training: 0.6707589285714286
# model accuracy after test: 0.7755102040816326
# model f1 score for training: 0.6919937205651491
# model precision score for test: 0.6247165532879818
# model recall score for test: 0.7755102040816326
# Training on India
# Average loss for epoch 1: 1.2246401995944325
# model accuracy after training: 0.5691964285714286
# model f1 score for training: 0.4137402204836415
# model precision score for training: 0.3249825418994413
# model recall score for training: 0.5691964285714286
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on Saudi Arabia
# Average loss for epoch 1: 1.2520218367119216
# model accuracy after training: 0.49330357142857145
# model f1 score for training: 0.35577983138780805
# model precision score for training: 0.32191174125045574
# model recall score for training: 0.49330357142857145
# model accuracy after test: 0.9659863945578231
# model f1 score for training: 0.9826989619377163
# model precision score for test: 1.0
# model recall score for test: 0.9659863945578231
# Training on Mexico
# Average loss for epoch 1: 1.2364799725124613
# model accuracy after training: 0.4921875
# model f1 score for training: 0.3246891361256545
# model precision score for training: 0.24224853515625
# model recall score for training: 0.4921875
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Japan
# Average loss for epoch 1: 1.238271960798143
# model accuracy after training: 0.5602678571428571
# model f1 score for training: 0.46926460113960117
# model precision score for training: 0.46705841553637484
# model recall score for training: 0.5602678571428571
# model accuracy after test: 0.08163265306122448
# model f1 score for training: 0.14939309056956118
# model precision score for test: 0.8791208791208791
# model recall score for test: 0.08163265306122448
# total train acc for epoch 1: 0.5488027597402597, total test acc for epoch 1: 0.5454545454545454
# total train f1 score for epoch 1: 0.410024025588187, total test f1 score for epoch 1: 0.5328987365182841
# total train precision score for epoch 1: 0.3500404289638502, total test precision score for epoch 1: 0.5931821543006276
# total train recall score for epoch 1: 0.5488027597402597, total test recall score for epoch 1: 0.5454545454545454
# Number of epoch: 2
# Training on Brazil
# Average loss for epoch 2: 1.5765465782023966
# model accuracy after training: 0.34486607142857145
# model f1 score for training: 0.23351606963112648
# model precision score for training: 0.22350449334106667
# model recall score for training: 0.34486607142857145
# model accuracy after test: 0.07482993197278912
# model f1 score for training: 0.014449917898193759
# model precision score for test: 0.007997091966557615
# model recall score for test: 0.07482993197278912
# Training on Germany
# Average loss for epoch 2: 1.2964999198447913
# model accuracy after training: 0.6651785714285714
# model f1 score for training: 0.531429528916124
# model precision score for training: 0.4424625318877551
# model recall score for training: 0.6651785714285714
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Italy
# Average loss for epoch 2: 1.1908223554491997
# model accuracy after training: 0.4799107142857143
# model f1 score for training: 0.31125430941607407
# model precision score for training: 0.2303142936862245
# model recall score for training: 0.4799107142857143
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on United States of America
# Average loss for epoch 2: 1.2147077019326389
# model accuracy after training: 0.6875
# model f1 score for training: 0.5601851851851852
# model precision score for training: 0.47265625
# model recall score for training: 0.6875
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on United Arab Emirates
# Average loss for epoch 2: 1.203354878537357
# model accuracy after training: 0.5859375
# model f1 score for training: 0.4329587438423645
# model precision score for training: 0.34332275390625
# model recall score for training: 0.5859375
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Israel
# Average loss for epoch 2: 1.202685468791363
# model accuracy after training: 0.5
# model f1 score for training: 0.3333333333333333
# model precision score for training: 0.25
# model recall score for training: 0.5
# model accuracy after test: 0.11564625850340136
# model f1 score for training: 0.023975443836071017
# model precision score for test: 0.013374057105835531
# model recall score for test: 0.11564625850340136
# Training on Republic of Korea
# Average loss for epoch 2: 1.2280002770213676
# model accuracy after training: 0.6808035714285714
# model f1 score for training: 0.5524183029785619
# model precision score for training: 0.46477204708699116
# model recall score for training: 0.6808035714285714
# model accuracy after test: 0.782312925170068
# model f1 score for training: 0.6927351093109
# model precision score for test: 0.621563693970739
# model recall score for test: 0.782312925170068
# Training on India
# Average loss for epoch 2: 1.2079078697424848
# model accuracy after training: 0.5703125
# model f1 score for training: 0.41425684079601993
# model precision score for training: 0.32525634765625
# model recall score for training: 0.5703125
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on Saudi Arabia
# Average loss for epoch 2: 1.2354865210492991
# model accuracy after training: 0.49330357142857145
# model f1 score for training: 0.36635362401386173
# model precision score for training: 0.3235235055795875
# model recall score for training: 0.49330357142857145
# model accuracy after test: 0.9455782312925171
# model f1 score for training: 0.9720279720279721
# model precision score for test: 1.0
# model recall score for test: 0.9455782312925171
# Training on Mexico
# Average loss for epoch 2: 1.2207279258174821
# model accuracy after training: 0.4921875
# model f1 score for training: 0.3246891361256545
# model precision score for training: 0.24224853515625
# model recall score for training: 0.4921875
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Japan
# Average loss for epoch 2: 1.2231414609123021
# model accuracy after training: 0.578125
# model f1 score for training: 0.47566964285714286
# model precision score for training: 0.49172794117647056
# model recall score for training: 0.578125
# model accuracy after test: 0.08163265306122448
# model f1 score for training: 0.15037593984962408
# model precision score for test: 0.9523809523809523
# model recall score for test: 0.08163265306122448
# total train acc for epoch 2: 0.5525568181818182, total test acc for epoch 2: 0.5454545454545454
# total train f1 score for epoch 2: 0.41236951973594976, total test f1 score for epoch 2: 0.5321422166293419
# total train precision score for epoch 2: 0.3463444272251678, total test precision score for epoch 2: 0.5995741632203713
# total train recall score for epoch 2: 0.5525568181818182, total test recall score for epoch 2: 0.5454545454545454
# Number of epoch: 3
# Training on Brazil
# Average loss for epoch 3: 1.553404205944389
# model accuracy after training: 0.33482142857142855
# model f1 score for training: 0.23920901514566256
# model precision score for training: 0.23679818211068213
# model recall score for training: 0.33482142857142855
# model accuracy after test: 0.061224489795918366
# model f1 score for training: 0.012889366272824918
# model precision score for test: 0.007202881152460984
# model recall score for test: 0.061224489795918366
# Training on Germany
# Average loss for epoch 3: 1.2780423574149609
# model accuracy after training: 0.6651785714285714
# model f1 score for training: 0.531429528916124
# model precision score for training: 0.4424625318877551
# model recall score for training: 0.6651785714285714
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Italy
# Average loss for epoch 3: 1.1766474756101768
# model accuracy after training: 0.4799107142857143
# model f1 score for training: 0.31125430941607407
# model precision score for training: 0.2303142936862245
# model recall score for training: 0.4799107142857143
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on United States of America
# Average loss for epoch 3: 1.2020970393205062
# model accuracy after training: 0.6875
# model f1 score for training: 0.5601851851851852
# model precision score for training: 0.47265625
# model recall score for training: 0.6875
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on United Arab Emirates
# Average loss for epoch 3: 1.1915781199932098
# model accuracy after training: 0.5859375
# model f1 score for training: 0.4329587438423645
# model precision score for training: 0.34332275390625
# model recall score for training: 0.5859375
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Israel
# Average loss for epoch 3: 1.1899735531769693
# model accuracy after training: 0.5
# model f1 score for training: 0.3333333333333333
# model precision score for training: 0.25
# model recall score for training: 0.5
# model accuracy after test: 0.11564625850340136
# model f1 score for training: 0.023975443836071017
# model precision score for test: 0.013374057105835531
# model recall score for test: 0.11564625850340136
# Training on Republic of Korea
# Average loss for epoch 3: 1.2149879283138685
# model accuracy after training: 0.6796875
# model f1 score for training: 0.5539226994410053
# model precision score for training: 0.6238463925368354
# model recall score for training: 0.6796875
# model accuracy after test: 0.7891156462585034
# model f1 score for training: 0.6961020149504669
# model precision score for test: 0.6227035031699755
# model recall score for test: 0.7891156462585034
# Training on India
# Average loss for epoch 3: 1.1955171080771834
# model accuracy after training: 0.5703125
# model f1 score for training: 0.41425684079601993
# model precision score for training: 0.32525634765625
# model recall score for training: 0.5703125
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on Saudi Arabia
# Average loss for epoch 3: 1.223271737082137
# model accuracy after training: 0.49330357142857145
# model f1 score for training: 0.3830744485294117
# model precision score for training: 0.3268339235740458
# model recall score for training: 0.49330357142857145
# model accuracy after test: 0.9455782312925171
# model f1 score for training: 0.9720279720279721
# model precision score for test: 1.0
# model recall score for test: 0.9455782312925171
# Training on Mexico
# Average loss for epoch 3: 1.2079099078197033
# model accuracy after training: 0.49107142857142855
# model f1 score for training: 0.32443820224719094
# model precision score for training: 0.24223993288590603
# model recall score for training: 0.49107142857142855
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Japan
# Average loss for epoch 3: 1.2104827456853606
# model accuracy after training: 0.5904017857142857
# model f1 score for training: 0.4797734085022297
# model precision score for training: 0.5195036114386792
# model recall score for training: 0.5904017857142857
# model accuracy after test: 0.07482993197278912
# model f1 score for training: 0.13875748975086724
# model precision score for test: 0.9523809523809523
# model recall score for test: 0.07482993197278912
# total train acc for epoch 3: 0.5525568181818182, total test acc for epoch 3: 0.54421768707483
# total train f1 score for epoch 3: 0.4148941559413274, total test f1 score for epoch 3: 0.531250207894382
# total train precision score for epoch 3: 0.3648394745166026, total test precision score for epoch 3: 0.599605581255384
# total train recall score for epoch 3: 0.5525568181818182, total test recall score for epoch 3: 0.54421768707483
# Number of epoch: 4
# Training on Brazil
# Average loss for epoch 4: 1.539666198194027
# model accuracy after training: 0.3325892857142857
# model f1 score for training: 0.24110598739328015
# model precision score for training: 0.21236438091721785
# model recall score for training: 0.3325892857142857
# model accuracy after test: 0.07482993197278912
# model f1 score for training: 0.015406162464985993
# model precision score for test: 0.00858704137392662
# model recall score for test: 0.07482993197278912
# Training on Germany
# Average loss for epoch 4: 1.266523733502254
# model accuracy after training: 0.6651785714285714
# model f1 score for training: 0.531429528916124
# model precision score for training: 0.4424625318877551
# model recall score for training: 0.6651785714285714
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Italy
# Average loss for epoch 4: 1.166848233435303
# model accuracy after training: 0.4799107142857143
# model f1 score for training: 0.31125430941607407
# model precision score for training: 0.2303142936862245
# model recall score for training: 0.4799107142857143
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on United States of America
# Average loss for epoch 4: 1.1896624066284858
# model accuracy after training: 0.6875
# model f1 score for training: 0.5601851851851852
# model precision score for training: 0.47265625
# model recall score for training: 0.6875
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on United Arab Emirates
# Average loss for epoch 4: 1.1783249357715249
# model accuracy after training: 0.5859375
# model f1 score for training: 0.4329587438423645
# model precision score for training: 0.34332275390625
# model recall score for training: 0.5859375
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Israel
# Average loss for epoch 4: 1.1778038119276364
# model accuracy after training: 0.5
# model f1 score for training: 0.3333333333333333
# model precision score for training: 0.25
# model recall score for training: 0.5
# model accuracy after test: 0.11564625850340136
# model f1 score for training: 0.023975443836071017
# model precision score for test: 0.013374057105835531
# model recall score for test: 0.11564625850340136
# Training on Republic of Korea
# Average loss for epoch 4: 1.2027978760057263
# model accuracy after training: 0.6808035714285714
# model f1 score for training: 0.5524183029785619
# model precision score for training: 0.46477204708699116
# model recall score for training: 0.6808035714285714
# model accuracy after test: 0.7755102040816326
# model f1 score for training: 0.6893424036281179
# model precision score for test: 0.6204081632653061
# model recall score for test: 0.7755102040816326
# Training on India
# Average loss for epoch 4: 1.1840331865823828
# model accuracy after training: 0.5703125
# model f1 score for training: 0.41425684079601993
# model precision score for training: 0.32525634765625
# model recall score for training: 0.5703125
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on Saudi Arabia
# Average loss for epoch 4: 1.2117769866664376
# model accuracy after training: 0.49107142857142855
# model f1 score for training: 0.3909664974917123
# model precision score for training: 0.3310249844816884
# model recall score for training: 0.49107142857142855
# model accuracy after test: 0.9455782312925171
# model f1 score for training: 0.9720279720279721
# model precision score for test: 1.0
# model recall score for test: 0.9455782312925171
# Training on Mexico
# Average loss for epoch 4: 1.197051017684862
# model accuracy after training: 0.4921875
# model f1 score for training: 0.3256634471117779
# model precision score for training: 0.2433348514573991
# model recall score for training: 0.4921875
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Japan
# Average loss for epoch 4: 1.2008116152984174
# model accuracy after training: 0.5926339285714286
# model f1 score for training: 0.48566240848974723
# model precision score for training: 0.5313603661593146
# model recall score for training: 0.5926339285714286
# model accuracy after test: 0.07482993197278912
# model f1 score for training: 0.13875748975086724
# model precision score for test: 0.9523809523809523
# model recall score for test: 0.07482993197278912
# total train acc for epoch 4: 0.5525568181818182, total test acc for epoch 4: 0.5442176870748299
# total train f1 score for epoch 4: 0.4162940531776528, total test f1 score for epoch 4: 0.5308644974280013
# total train precision score for epoch 4: 0.3497153461126446, total test precision score for epoch 4: 0.5995227467387292
# total train recall score for epoch 4: 0.5525568181818182, total test recall score for epoch 4: 0.5442176870748299
# Number of epoch: 5
# Training on Brazil
# Average loss for epoch 5: 1.5103231789544225
# model accuracy after training: 0.34933035714285715
# model f1 score for training: 0.2668799740942677
# model precision score for training: 0.24553089618617413
# model recall score for training: 0.34933035714285715
# model accuracy after test: 0.047619047619047616
# model f1 score for training: 0.010335917312661501
# model precision score for test: 0.005797101449275363
# model recall score for test: 0.047619047619047616
# Training on Germany
# Average loss for epoch 5: 1.2509890524670482
# model accuracy after training: 0.6651785714285714
# model f1 score for training: 0.531429528916124
# model precision score for training: 0.4424625318877551
# model recall score for training: 0.6651785714285714
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Italy
# Average loss for epoch 5: 1.1540527750427525
# model accuracy after training: 0.4799107142857143
# model f1 score for training: 0.31125430941607407
# model precision score for training: 0.2303142936862245
# model recall score for training: 0.4799107142857143
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on United States of America
# Average loss for epoch 5: 1.179002784192562
# model accuracy after training: 0.6875
# model f1 score for training: 0.5601851851851852
# model precision score for training: 0.47265625
# model recall score for training: 0.6875
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on United Arab Emirates
# Average loss for epoch 5: 1.1663247304502875
# model accuracy after training: 0.5859375
# model f1 score for training: 0.4329587438423645
# model precision score for training: 0.34332275390625
# model recall score for training: 0.5859375
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Israel
# Average loss for epoch 5: 1.167646609285536
# model accuracy after training: 0.5
# model f1 score for training: 0.3333333333333333
# model precision score for training: 0.25
# model recall score for training: 0.5
# model accuracy after test: 0.11564625850340136
# model f1 score for training: 0.023975443836071017
# model precision score for test: 0.013374057105835531
# model recall score for test: 0.11564625850340136
# Training on Republic of Korea
# Average loss for epoch 5: 1.1912442386216884
# model accuracy after training: 0.6808035714285714
# model f1 score for training: 0.5555741882617714
# model precision score for training: 0.7846972813001605
# model recall score for training: 0.6808035714285714
# model accuracy after test: 0.782312925170068
# model f1 score for training: 0.6953892668178383
# model precision score for test: 0.6258503401360545
# model recall score for test: 0.782312925170068
# Training on India
# Average loss for epoch 5: 1.1724312028673012
# model accuracy after training: 0.5691964285714286
# model f1 score for training: 0.4137402204836415
# model precision score for training: 0.3249825418994413
# model recall score for training: 0.5691964285714286
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on Saudi Arabia
# Average loss for epoch 5: 1.200620630161009
# model accuracy after training: 0.5078125
# model f1 score for training: 0.40986925120440015
# model precision score for training: 0.34807219015335294
# model recall score for training: 0.5078125
# model accuracy after test: 0.8435374149659864
# model f1 score for training: 0.915129151291513
# model precision score for test: 1.0
# model recall score for test: 0.8435374149659864
# Training on Mexico
# Average loss for epoch 5: 1.185096157924272
# model accuracy after training: 0.49441964285714285
# model f1 score for training: 0.3312212727767506
# model precision score for training: 0.3176231914693724
# model recall score for training: 0.49441964285714285
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Japan
# Average loss for epoch 5: 1.1890203193126416
# model accuracy after training: 0.5691964285714286
# model f1 score for training: 0.47611867116773476
# model precision score for training: 0.4848130325534319
# model recall score for training: 0.5691964285714286
# model accuracy after test: 0.11564625850340136
# model f1 score for training: 0.20624810433727633
# model precision score for test: 0.9523809523809523
# model recall score for test: 0.11564625850340136
# total train acc for epoch 5: 0.5535714285714287, total test acc for epoch 5: 0.5367965367965368
# total train f1 score for epoch 5: 0.4202331526074224, total test f1 score for epoch 5: 0.5319161712359418
# total train precision score for epoch 5: 0.38586136027656026, total test precision score for epoch 5: 0.5997638591883743
# total train recall score for epoch 5: 0.5535714285714287, total test recall score for epoch 5: 0.5367965367965368
# Number of epoch: 6
# Training on Brazil
# Average loss for epoch 6: 1.4883465939201415
# model accuracy after training: 0.3794642857142857
# model f1 score for training: 0.30084814525980785
# model precision score for training: 0.2799520843862309
# model recall score for training: 0.3794642857142857
# model accuracy after test: 0.04081632653061224
# model f1 score for training: 0.008592910848549946
# model precision score for test: 0.0048019207683073235
# model recall score for test: 0.04081632653061224
# Training on Germany
# Average loss for epoch 6: 1.2374757051002234
# model accuracy after training: 0.6651785714285714
# model f1 score for training: 0.531429528916124
# model precision score for training: 0.4424625318877551
# model recall score for training: 0.6651785714285714
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Italy
# Average loss for epoch 6: 1.144708019060393
# model accuracy after training: 0.4799107142857143
# model f1 score for training: 0.31125430941607407
# model precision score for training: 0.2303142936862245
# model recall score for training: 0.4799107142857143
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on United States of America
# Average loss for epoch 6: 1.1714791517006233
# model accuracy after training: 0.6875
# model f1 score for training: 0.5601851851851852
# model precision score for training: 0.47265625
# model recall score for training: 0.6875
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on United Arab Emirates
# Average loss for epoch 6: 1.1574647622182965
# model accuracy after training: 0.5859375
# model f1 score for training: 0.4329587438423645
# model precision score for training: 0.34332275390625
# model recall score for training: 0.5859375
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Israel
# Average loss for epoch 6: 1.1563247009180486
# model accuracy after training: 0.5
# model f1 score for training: 0.3333333333333333
# model precision score for training: 0.25
# model recall score for training: 0.5
# model accuracy after test: 0.11564625850340136
# model f1 score for training: 0.023975443836071017
# model precision score for test: 0.013374057105835531
# model recall score for test: 0.11564625850340136
# Training on Republic of Korea
# Average loss for epoch 6: 1.1804985598927098
# model accuracy after training: 0.6741071428571429
# model f1 score for training: 0.5550912910681276
# model precision score for training: 0.7845753855519481
# model recall score for training: 0.6741071428571429
# model accuracy after test: 0.7414965986394558
# model f1 score for training: 0.6719812925170069
# model precision score for test: 0.6143828960155491
# model recall score for test: 0.7414965986394558
# Training on India
# Average loss for epoch 6: 1.1607263494515792
# model accuracy after training: 0.5703125
# model f1 score for training: 0.4185000504186169
# model precision score for training: 0.4633014169472502
# model recall score for training: 0.5703125
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on Saudi Arabia
# Average loss for epoch 6: 1.186539460853156
# model accuracy after training: 0.5022321428571429
# model f1 score for training: 0.40212536403564575
# model precision score for training: 0.3826438037474107
# model recall score for training: 0.5022321428571429
# model accuracy after test: 0.8435374149659864
# model f1 score for training: 0.915129151291513
# model precision score for test: 1.0
# model recall score for test: 0.8435374149659864
# Training on Mexico
# Average loss for epoch 6: 1.1706013342831283
# model accuracy after training: 0.5
# model f1 score for training: 0.3463200731814447
# model precision score for training: 0.32720301674364893
# model recall score for training: 0.5
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Japan
# Average loss for epoch 6: 1.1756574120372534
# model accuracy after training: 0.5691964285714286
# model f1 score for training: 0.5071610884603818
# model precision score for training: 0.5188853346456693
# model recall score for training: 0.5691964285714286
# model accuracy after test: 0.24489795918367346
# model f1 score for training: 0.3896103896103896
# model precision score for test: 0.9523809523809523
# model recall score for test: 0.24489795918367346
# total train acc for epoch 6: 0.5558035714285715, total test acc for epoch 6: 0.54421768707483
# total train f1 score for epoch 6: 0.4272006466470096, total test f1 score for epoch 6: 0.5462990171003209
# total train precision score for epoch 6: 0.40866517013658066, total test precision score for epoch 6: 0.5986308932973313
# total train recall score for epoch 6: 0.5558035714285715, total test recall score for epoch 6: 0.54421768707483
# Number of epoch: 7
# Training on Brazil
# Average loss for epoch 7: 1.4564081151038408
# model accuracy after training: 0.41517857142857145
# model f1 score for training: 0.3278466765626111
# model precision score for training: 0.30831637855159416
# model recall score for training: 0.41517857142857145
# model accuracy after test: 0.04081632653061224
# model f1 score for training: 0.008658008658008658
# model precision score for test: 0.004842615012106539
# model recall score for test: 0.04081632653061224
# Training on Germany
# Average loss for epoch 7: 1.221365294419229
# model accuracy after training: 0.6618303571428571
# model f1 score for training: 0.5298198695193322
# model precision score for training: 0.44171432570788677
# model recall score for training: 0.6618303571428571
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Italy
# Average loss for epoch 7: 1.1330319706661005
# model accuracy after training: 0.4799107142857143
# model f1 score for training: 0.3153931352514793
# model precision score for training: 0.42606521564854904
# model recall score for training: 0.4799107142857143
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on United States of America
# Average loss for epoch 7: 1.1600256868987344
# model accuracy after training: 0.6875
# model f1 score for training: 0.5605559232296492
# model precision score for training: 0.47318435754189947
# model recall score for training: 0.6875
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on United Arab Emirates
# Average loss for epoch 7: 1.1451516485307365
# model accuracy after training: 0.5870535714285714
# model f1 score for training: 0.43547125818095384
# model precision score for training: 0.4441527833200319
# model recall score for training: 0.5870535714285714
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Israel
# Average loss for epoch 7: 1.1451537657218676
# model accuracy after training: 0.5044642857142857
# model f1 score for training: 0.3433349114477756
# model precision score for training: 0.47908148949815615
# model recall score for training: 0.5044642857142857
# model accuracy after test: 0.11564625850340136
# model f1 score for training: 0.023975443836071017
# model precision score for test: 0.013374057105835531
# model recall score for test: 0.11564625850340136
# Training on Republic of Korea
# Average loss for epoch 7: 1.1705151205616338
# model accuracy after training: 0.6674107142857143
# model f1 score for training: 0.5537494401449118
# model precision score for training: 0.6243408523099606
# model recall score for training: 0.6674107142857143
# model accuracy after test: 0.7619047619047619
# model f1 score for training: 0.682478396764111
# model precision score for test: 0.6180486180486181
# model recall score for test: 0.7619047619047619
# Training on India
# Average loss for epoch 7: 1.1494975998357404
# model accuracy after training: 0.5680803571428571
# model f1 score for training: 0.4174342757936508
# model precision score for training: 0.4234656214848144
# model recall score for training: 0.5680803571428571
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on Saudi Arabia
# Average loss for epoch 7: 1.1769646011655115
# model accuracy after training: 0.5089285714285714
# model f1 score for training: 0.41413074821701307
# model precision score for training: 0.3845684739478773
# model recall score for training: 0.5089285714285714
# model accuracy after test: 0.8775510204081632
# model f1 score for training: 0.9347826086956522
# model precision score for test: 1.0
# model recall score for test: 0.8775510204081632
# Training on Mexico
# Average loss for epoch 7: 1.1622135273879395
# model accuracy after training: 0.4921875
# model f1 score for training: 0.34171052322143686
# model precision score for training: 0.27426019398258117
# model recall score for training: 0.4921875
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Japan
# Average loss for epoch 7: 1.1674823632929474
# model accuracy after training: 0.5602678571428571
# model f1 score for training: 0.5265942265936477
# model precision score for training: 0.5314641999018355
# model recall score for training: 0.5602678571428571
# model accuracy after test: 0.23809523809523808
# model f1 score for training: 0.38095238095238093
# model precision score for test: 0.9523809523809523
# model recall score for test: 0.23809523809523808
# total train acc for epoch 7: 0.5575284090909091, total test acc for epoch 7: 0.5485466914038343
# total train f1 score for epoch 7: 0.4332764534693147, total test f1 score for epoch 7: 0.5482588035369294
# total train precision score for epoch 7: 0.4373285356268351, total test precision score for epoch 7: 0.598967840231592
# total train recall score for epoch 7: 0.5575284090909091, total test recall score for epoch 7: 0.5485466914038343
# Number of epoch: 8
# Training on Brazil
# Average loss for epoch 8: 1.4388314541429281
# model accuracy after training: 0.39732142857142855
# model f1 score for training: 0.30649545613986173
# model precision score for training: 0.2840733034967809
# model recall score for training: 0.39732142857142855
# model accuracy after test: 0.05442176870748299
# model f1 score for training: 0.01163213376953835
# model precision score for test: 0.0065120065120065134
# model recall score for test: 0.05442176870748299
# Training on Germany
# Average loss for epoch 8: 1.2133470000699162
# model accuracy after training: 0.6651785714285714
# model f1 score for training: 0.531429528916124
# model precision score for training: 0.4424625318877551
# model recall score for training: 0.6651785714285714
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Italy
# Average loss for epoch 8: 1.130259140394628
# model accuracy after training: 0.4810267857142857
# model f1 score for training: 0.3178207631332631
# model precision score for training: 0.47520816613162115
# model recall score for training: 0.4810267857142857
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on United States of America
# Average loss for epoch 8: 1.154153851151932
# model accuracy after training: 0.6863839285714286
# model f1 score for training: 0.5596459298477828
# model precision score for training: 0.4724162011173184
# model recall score for training: 0.6863839285714286
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on United Arab Emirates
# Average loss for epoch 8: 1.1364385531283916
# model accuracy after training: 0.5870535714285714
# model f1 score for training: 0.43547125818095384
# model precision score for training: 0.4441527833200319
# model recall score for training: 0.5870535714285714
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Israel
# Average loss for epoch 8: 1.1358275324261438
# model accuracy after training: 0.5033482142857143
# model f1 score for training: 0.3411456944148085
# model precision score for training: 0.4221618466410133
# model recall score for training: 0.5033482142857143
# model accuracy after test: 0.11564625850340136
# model f1 score for training: 0.023975443836071017
# model precision score for test: 0.013374057105835531
# model recall score for test: 0.11564625850340136
# Training on Republic of Korea
# Average loss for epoch 8: 1.1603750884532928
# model accuracy after training: 0.6506696428571429
# model f1 score for training: 0.5417880664621564
# model precision score for training: 0.514498546511628
# model recall score for training: 0.6506696428571429
# model accuracy after test: 0.7414965986394558
# model f1 score for training: 0.6719812925170069
# model precision score for test: 0.6143828960155491
# model recall score for test: 0.7414965986394558
# Training on India
# Average loss for epoch 8: 1.139045426651137
# model accuracy after training: 0.5636160714285714
# model f1 score for training: 0.41529485413990713
# model precision score for training: 0.3866437146892655
# model recall score for training: 0.5636160714285714
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on Saudi Arabia
# Average loss for epoch 8: 1.1659810454843358
# model accuracy after training: 0.5111607142857143
# model f1 score for training: 0.40473078274730195
# model precision score for training: 0.394067275295044
# model recall score for training: 0.5111607142857143
# model accuracy after test: 0.891156462585034
# model f1 score for training: 0.9424460431654677
# model precision score for test: 1.0
# model recall score for test: 0.891156462585034
# Training on Mexico
# Average loss for epoch 8: 1.1508444097125903
# model accuracy after training: 0.48325892857142855
# model f1 score for training: 0.3440312933702118
# model precision score for training: 0.3589409722222222
# model recall score for training: 0.48325892857142855
# model accuracy after test: 0.9931972789115646
# model f1 score for training: 0.9965870307167234
# model precision score for test: 1.0
# model recall score for test: 0.9931972789115646
# Training on Japan
# Average loss for epoch 8: 1.1564393580510197
# model accuracy after training: 0.546875
# model f1 score for training: 0.5167371245692676
# model precision score for training: 0.5165221445315876
# model recall score for training: 0.546875
# model accuracy after test: 0.3129251700680272
# model f1 score for training: 0.4685510567863509
# model precision score for test: 0.9321175278622086
# model recall score for test: 0.3129251700680272
# total train acc for epoch 8: 0.5523538961038962, total test acc for epoch 8: 0.5553494124922697
# total train f1 score for epoch 8: 0.42859915926560355, total test f1 score for epoch 8: 0.5559248182537416
# total train precision score for epoch 8: 0.42828613507675156, total test precision score for epoch 8: 0.5969442261359637
# total train recall score for epoch 8: 0.5523538961038962, total test recall score for epoch 8: 0.5553494124922697
# Number of epoch: 9
# Training on Brazil
# Average loss for epoch 9: 1.397059726063162
# model accuracy after training: 0.4263392857142857
# model f1 score for training: 0.3156018220013922
# model precision score for training: 0.29648768206191267
# model recall score for training: 0.4263392857142857
# model accuracy after test: 0.08163265306122448
# model f1 score for training: 0.01576354679802956
# model precision score for test: 0.008724100327153761
# model recall score for test: 0.08163265306122448
# Training on Germany
# ...
# Number of epoch: 97
# Training on Brazil
# Average loss for epoch 97: 1.2075529447756708
# model accuracy after training: 0.48214285714285715
# model f1 score for training: 0.439505584265957
# model precision score for training: 0.4392190712302892
# model recall score for training: 0.48214285714285715
# model accuracy after test: 0.41496598639455784
# model f1 score for training: 0.51515034407422
# model precision score for test: 0.9168035030103997
# model recall score for test: 0.41496598639455784
# Training on Germany
# Average loss for epoch 97: 1.0533443016465753
# model accuracy after training: 0.6651785714285714
# model f1 score for training: 0.5334670608108107
# model precision score for training: 0.6067708333333333
# model recall score for training: 0.6651785714285714
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Italy
# Average loss for epoch 97: 1.007706667141368
# model accuracy after training: 0.4810267857142857
# model f1 score for training: 0.3176000846226499
# model precision score for training: 0.5238330727914061
# model recall score for training: 0.4810267857142857
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on United States of America
# Average loss for epoch 97: 1.0480696117738262
# model accuracy after training: 0.6796875
# model f1 score for training: 0.5578780812791472
# model precision score for training: 0.47309322033898304
# model recall score for training: 0.6796875
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on United Arab Emirates
# Average loss for epoch 97: 1.017711094301194
# model accuracy after training: 0.6517857142857143
# model f1 score for training: 0.5552616520714482
# model precision score for training: 0.5090001719804996
# model recall score for training: 0.6517857142857143
# model accuracy after test: 0.9727891156462585
# model f1 score for training: 0.9862068965517241
# model precision score for test: 1.0
# model recall score for test: 0.9727891156462585
# Training on Israel
# Average loss for epoch 97: 1.032829536202674
# model accuracy after training: 0.5133928571428571
# model f1 score for training: 0.4107154723453733
# model precision score for training: 0.4134031001293101
# model recall score for training: 0.5133928571428571
# model accuracy after test: 0.10884353741496598
# model f1 score for training: 0.02312925170068027
# model precision score for test: 0.012939441510870082
# model recall score for test: 0.10884353741496598
# Training on Republic of Korea
# Average loss for epoch 97: 1.060041951481253
# model accuracy after training: 0.6529017857142857
# model f1 score for training: 0.5533779161866359
# model precision score for training: 0.5512152777777778
# model recall score for training: 0.6529017857142857
# model accuracy after test: 0.7006802721088435
# model f1 score for training: 0.6502312925170067
# model precision score for test: 0.6065590415270585
# model recall score for test: 0.7006802721088435
# Training on India
# Average loss for epoch 97: 1.04571784993459
# model accuracy after training: 0.5859375
# model f1 score for training: 0.455156851799019
# model precision score for training: 0.6254763096600195
# model recall score for training: 0.5859375
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on Saudi Arabia
# Average loss for epoch 97: 1.0598413723443325
# model accuracy after training: 0.5491071428571429
# model f1 score for training: 0.4305053368943576
# model precision score for training: 0.3933477876701993
# model recall score for training: 0.5491071428571429
# model accuracy after test: 0.8843537414965986
# model f1 score for training: 0.9386281588447654
# model precision score for test: 1.0
# model recall score for test: 0.8843537414965986
# Training on Mexico
# Average loss for epoch 97: 1.0490393485524692
# model accuracy after training: 0.5658482142857143
# model f1 score for training: 0.45443327739676054
# model precision score for training: 0.47103552018633543
# model recall score for training: 0.5658482142857143
# model accuracy after test: 0.9863945578231292
# model f1 score for training: 0.9931506849315067
# model precision score for test: 1.0
# model recall score for test: 0.9863945578231292
# Training on Japan
# Average loss for epoch 97: 1.057867638692683
# model accuracy after training: 0.5435267857142857
# model f1 score for training: 0.5044216456815642
# model precision score for training: 0.5092832605842154
# model recall score for training: 0.5435267857142857
# model accuracy after test: 0.3333333333333333
# model f1 score for training: 0.4938271604938272
# model precision score for test: 0.9523809523809523
# model recall score for test: 0.3333333333333333
# total train acc for epoch 97: 0.5791396103896105, total test acc for epoch 97: 0.5819418676561532
# total train f1 score for epoch 97: 0.47384754212306573, total test f1 score for epoch 97: 0.6000294353739756
# total train precision score for epoch 97: 0.5014252386983972, total test precision score for epoch 97: 0.6807893580390255
# total train recall score for epoch 97: 0.5791396103896105, total test recall score for epoch 97: 0.5819418676561532
# Number of epoch: 98
# Training on Brazil
# Average loss for epoch 98: 1.1989149823784828
# model accuracy after training: 0.5
# model f1 score for training: 0.4583180186353033
# model precision score for training: 0.49230433893634934
# model recall score for training: 0.5
# model accuracy after test: 0.47619047619047616
# model f1 score for training: 0.5793320105820106
# model precision score for test: 0.9185463659147869
# model recall score for test: 0.47619047619047616
# Training on Germany
# Average loss for epoch 98: 1.0333618300501257
# model accuracy after training: 0.6640625
# model f1 score for training: 0.5329229222572069
# model precision score for training: 0.5518342065269557
# model recall score for training: 0.6640625
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on Italy
# Average loss for epoch 98: 0.9958649260612825
# model accuracy after training: 0.48214285714285715
# model f1 score for training: 0.3163940179246302
# model precision score for training: 0.5569808830587106
# model recall score for training: 0.48214285714285715
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on United States of America
# Average loss for epoch 98: 1.0414389248762745
# model accuracy after training: 0.6785714285714286
# model f1 score for training: 0.5593654284143563
# model precision score for training: 0.5668934240362812
# model recall score for training: 0.6785714285714286
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on United Arab Emirates
# Average loss for epoch 98: 1.0126367847202347
# model accuracy after training: 0.6462053571428571
# model f1 score for training: 0.5505414359799864
# model precision score for training: 0.6039634181375252
# model recall score for training: 0.6462053571428571
# model accuracy after test: 0.9863945578231292
# model f1 score for training: 0.9931506849315067
# model precision score for test: 1.0
# model recall score for test: 0.9863945578231292
# Training on Israel
# Average loss for epoch 98: 1.0267141233586397
# model accuracy after training: 0.5290178571428571
# model f1 score for training: 0.42992947428587974
# model precision score for training: 0.4367748483972216
# model recall score for training: 0.5290178571428571
# model accuracy after test: 0.11564625850340136
# model f1 score for training: 0.024574829931972787
# model precision score for test: 0.01374815660529946
# model recall score for test: 0.11564625850340136
# Training on Republic of Korea
# Average loss for epoch 98: 1.0548275822574007
# model accuracy after training: 0.6372767857142857
# model f1 score for training: 0.5474443976105493
# model precision score for training: 0.530887884814943
# model recall score for training: 0.6372767857142857
# model accuracy after test: 0.7142857142857143
# model f1 score for training: 0.6575963718820861
# model precision score for test: 0.6092436974789917
# model recall score for test: 0.7142857142857143
# Training on India
# Average loss for epoch 98: 1.040560883237049
# model accuracy after training: 0.5926339285714286
# model f1 score for training: 0.46561753624234986
# model precision score for training: 0.7326964966842839
# model recall score for training: 0.5926339285714286
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on Saudi Arabia
# Average loss for epoch 98: 1.054762265489747
# model accuracy after training: 0.5591517857142857
# model f1 score for training: 0.4453758579248398
# model precision score for training: 0.41408716344545254
# model recall score for training: 0.5591517857142857
# model accuracy after test: 0.8979591836734694
# model f1 score for training: 0.9462365591397849
# model precision score for test: 1.0
# model recall score for test: 0.8979591836734694
# Training on Mexico
# Average loss for epoch 98: 1.0442919126478956
# model accuracy after training: 0.5446428571428571
# model f1 score for training: 0.4289741584094355
# model precision score for training: 0.4384181697379755
# model recall score for training: 0.5446428571428571
# model accuracy after test: 0.9863945578231292
# model f1 score for training: 0.9931506849315067
# model precision score for test: 1.0
# model recall score for test: 0.9863945578231292
# Training on Japan
# Average loss for epoch 98: 1.05331879589622
# model accuracy after training: 0.5613839285714286
# model f1 score for training: 0.5143239395129615
# model precision score for training: 0.5346293852179836
# model recall score for training: 0.5613839285714286
# model accuracy after test: 0.30612244897959184
# model f1 score for training: 0.46332046332046334
# model precision score for test: 0.9523809523809523
# model recall score for test: 0.30612244897959184
# total train acc for epoch 98: 0.5813717532467533, total test acc for epoch 98: 0.5893630179344466
# total train f1 score for epoch 98: 0.47720065338159084, total test f1 score for epoch 98: 0.605214691338121
# total train precision score for epoch 98: 0.5326791108176074, total test precision score for epoch 98: 0.6812653793072755
# total train recall score for epoch 98: 0.5813717532467533, total test recall score for epoch 98: 0.5893630179344466
# Number of epoch: 99
# Training on Brazil
# Average loss for epoch 99: 1.2266735676676035
# model accuracy after training: 0.5189732142857143
# model f1 score for training: 0.4693971161746465
# model precision score for training: 0.47478969280176125
# model recall score for training: 0.5189732142857143
# model accuracy after test: 0.42857142857142855
# model f1 score for training: 0.5350533454549253
# model precision score for test: 0.9160997732426304
# model recall score for test: 0.42857142857142855
# Training on Germany
# Average loss for epoch 99: 1.0550999435363337
# model accuracy after training: 0.6651785714285714
# model f1 score for training: 0.531429528916124
# model precision score for training: 0.4424625318877551
# model recall score for training: 0.6651785714285714
# model accuracy after test: 0.9931972789115646
# model f1 score for training: 0.9965870307167234
# model precision score for test: 1.0
# model recall score for test: 0.9931972789115646
# Training on Italy
# Average loss for epoch 99: 1.0129278131450217
# model accuracy after training: 0.4799107142857143
# model f1 score for training: 0.31125430941607407
# model precision score for training: 0.2303142936862245
# model recall score for training: 0.4799107142857143
# model accuracy after test: 1.0
# model f1 score for training: 1.0
# model precision score for test: 1.0
# model recall score for test: 1.0
# Training on United States of America
# Average loss for epoch 99: 1.0501486069115344
# model accuracy after training: 0.6785714285714286
# model f1 score for training: 0.5588235294117647
# model precision score for training: 0.47500000000000003
# model recall score for training: 0.6785714285714286
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on United Arab Emirates
# Average loss for epoch 99: 1.0211344164097682
# model accuracy after training: 0.6450892857142857
# model f1 score for training: 0.5476217017127217
# model precision score for training: 0.5033644328459376
# model recall score for training: 0.6450892857142857
# model accuracy after test: 0.9931972789115646
# model f1 score for training: 0.9965870307167234
# model precision score for test: 1.0
# model recall score for test: 0.9931972789115646
# Training on Israel
# Average loss for epoch 99: 1.0309186623586963
# model accuracy after training: 0.5267857142857143
# model f1 score for training: 0.42613719134002803
# model precision score for training: 0.42752319476672074
# model recall score for training: 0.5267857142857143
# model accuracy after test: 0.11564625850340136
# model f1 score for training: 0.024271436969849666
# model precision score for test: 0.01355852685901947
# model recall score for test: 0.11564625850340136
# Training on Republic of Korea
# Average loss for epoch 99: 1.0570638503081031
# model accuracy after training: 0.6350446428571429
# model f1 score for training: 0.5577799096439818
# model precision score for training: 0.5988140965923207
# model recall score for training: 0.6350446428571429
# model accuracy after test: 0.6666666666666666
# model f1 score for training: 0.633879781420765
# model precision score for test: 0.6041666666666666
# model recall score for test: 0.6666666666666666
# Training on India
# Average loss for epoch 99: 1.0412877448834479
# model accuracy after training: 0.5915178571428571
# model f1 score for training: 0.46839407266499744
# model precision score for training: 0.6387866467795741
# model recall score for training: 0.5915178571428571
# model accuracy after test: 0.0
# model f1 score for training: 0.0
# model precision score for test: 0.0
# model recall score for test: 0.0
# Training on Saudi Arabia
# Average loss for epoch 99: 1.0558011155937694
# model accuracy after training: 0.5546875
# model f1 score for training: 0.42974457107633846
# model precision score for training: 0.3860506860237463
# model recall score for training: 0.5546875
# model accuracy after test: 0.9047619047619048
# model f1 score for training: 0.9500000000000001
# model precision score for test: 1.0
# model recall score for test: 0.9047619047619048
# Training on Mexico
# Average loss for epoch 99: 1.0476662409026176
# model accuracy after training: 0.5613839285714286
# model f1 score for training: 0.4509453546163306
# model precision score for training: 0.47141299832615796
# model recall score for training: 0.5613839285714286
# model accuracy after test: 0.9931972789115646
# model f1 score for training: 0.9965870307167234
# model precision score for test: 1.0
# model recall score for test: 0.9931972789115646
# Training on Japan
# Average loss for epoch 99: 1.0573880364271728
# model accuracy after training: 0.5546875
# model f1 score for training: 0.5104140513289999
# model precision score for training: 0.5158727993109203
# model recall score for training: 0.5546875
# model accuracy after test: 0.3197278911564626
# model f1 score for training: 0.4787369493251846
# model precision score for test: 0.9523809523809523
# model recall score for test: 0.31972789115646255
# total train acc for epoch 99: 0.5828936688311689, total test acc for epoch 99: 0.5831787260358688
# total train f1 score for epoch 99: 0.47835830330018253, total test f1 score for epoch 99: 0.6010638732109904
# total train precision score for epoch 99: 0.4694901248201017, total test precision score for epoch 99: 0.6805641744681153
# total train recall score for epoch 99: 0.5828936688311689, total test recall score for epoch 99: 0.5831787260358688
